# %% [markdown]
# # Route Plan Analysis

# %% [markdown]
# Use this notebook to map and analyze a routing plan from Azavea's [School Bus Routing Optimization tool](https://github.com/azavea/bus-plan). Update the cell below to point to local copies of solver output.

# %%
import sys
import os

# %%
sys.path.append('..')

# %%
import bus_plan_analytics.post_processing.drive_distances as dr
import bus_plan_analytics.plan_analysis as pa

# %% [markdown]
# ## Inputs
#
# Specify the locations of input files

# %%
# Base directory
base_dir = '< input base directory >'
base_dir = '/run/user/1000/gvfs/smb-share:server=fileshare,share=projects/PhilaSchoolDistrict_BusRouting/data/'

# Cost Matrix
cost_matrix_csv = os.path.join(base_dir, 'bus-plan-input-updated-jan-12/chester-cost-matrix.csv')

# Existing router output/student assignment csv 
existing_routes = os.path.join(base_dir, 'existing/OUTPUT_router.csv')
existing_student_assignment = os.path.join(base_dir, 'existing/OUTPUT_solver_student_assignment.csv')
existing_routes_dir = os.path.join(base_dir, 'existing/')

# Directory with all solver/router output for all iterations of solver
directory = os.path.join(base_dir, 'chester-output-jan-12')

# Directory with all student-stop eligibility files for all scenarios
eligibility_csv_directory = os.path.join(base_dir, 'bus-plan-input-updated-jan-8-METERS/')

# Directory for iterations with outliers removed
without_outliers = os.path.join(base_dir, 'chester-output-jan-12-REMOVE-OUTLIERS')

# %% [markdown]
# ## Cost Matrix
#
# Read in cost matrix in order to calculate mileage.

# %%
cm = dr.cost_matrix(cost_matrix_csv)
# Out:
# ../bus_plan_analytics/post_processing/drive_distances.py:25: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   dtype=None, names=True)

# %% [markdown]
# ## Investigating student-stop eligibility

# %%
student_stop_plot = pa.student_stop_eligibility_plots(eligibility_csv_directory)

# %% [markdown]
# ## Existing plans

# %%
ex = pa.BusPlan(existing_routes_dir, cost_matrix = cm)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-6054b5204068> in <module>()
# ----> 1 ex = pa.BusPlan(existing_routes_dir, cost_matrix = cm)
#
# ~/files/da_customer/bus_routing/bus-plan/bus_plan_analytics/plan_analysis.py in __init__(self, plan_dir, total_students, cost_matrix)
#      57         os.chdir(plan_dir)  # switch to plan directory
#      58         self.ride_times_df = pd.read_csv(
# ---> 59             'OUTPUT_analysis_student_ride_times.csv')
#      60         self.plan = pd.read_csv('OUTPUT_router.csv')
#      61         self.routed_students = self.get_routed_students()
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'OUTPUT_analysis_student_ride_times.csv' does not exist

# %%
ex.map()

# %%
ex.animate()

# %%
ex.bus_metrics

# %%
ex.student_metrics

# %%
ex.plot_student_ride_time()

# %% [markdown]
# ## Proposed plans

# %%
plans = pa.get_all_plans(directory, cm)
# Out:
# Failed to caluclate student ride time metrics for run student-walk-0.50m-or-1.0m_run0
# Failed to caluclate student ride time metrics for run student-walk-0.50m-or-1.0m_run1
# Failed to caluclate student ride time metrics for run student-walk-0.50m-or-1.0m_run2
# Failed to caluclate student ride time metrics for run student-walk-0.50m-or-1.0m_run3
# Failed to caluclate student ride time metrics for run student-walk-0.50m_run0
# Failed to caluclate student ride time metrics for run student-walk-0.50m_run1
# Failed to caluclate student ride time metrics for run student-walk-0.50m_run2
# Failed to caluclate student ride time metrics for run student-walk-0.50m_run3
# Failed to caluclate student ride time metrics for run student-walk-0.40m_run0
# Failed to caluclate student ride time metrics for run student-walk-0.40m_run1
# Failed to caluclate student ride time metrics for run student-walk-0.40m_run2
# Failed to caluclate student ride time metrics for run student-walk-0.40m_run3
# Failed to caluclate student ride time metrics for run student-walk-0.25m_run1
# Failed to caluclate student ride time metrics for run student-walk-0.25m_run3
# Failed to caluclate student ride time metrics for run student-walk-0.82m_run0
# Failed to caluclate student ride time metrics for run student-walk-0.82m_run1
# Failed to caluclate student ride time metrics for run student-walk-0.82m_run2
# Failed to caluclate student ride time metrics for run student-walk-0.82m_run3
# Failed to caluclate student ride time metrics for run student-walk-0.25m_run0
# Failed to caluclate student ride time metrics for run student-walk-0.25m_run2

# %% [markdown]
# ### Scenario 1: Quarter mile student walk distance limit

# %% [markdown]
# ##### Run #1

# %%
p = plans['student-walk-0.25m_run0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-9076d17731e2> in <module>()
# ----> 1 p = plans['student-walk-0.25m_run0']
#
# KeyError: 'student-walk-0.25m_run0'

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #2

# %%
p = plans['student-walk-0.25m_run1']

# %%
p.map()

# %%
p.animate()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #3

# %%
p = plans['student-walk-0.25m_run2']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #4

# %%
p = plans['student-walk-0.25m_run3']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ### Scenario 2: 0.4 mile student walk distance limit

# %% [markdown]
# ##### Run #1

# %%
p = plans['student-walk-0.40m_run0']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #2

# %%
p = plans['student-walk-0.40m_run1']

# %%
p.map()

# %%
p.animate()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #3

# %%
p = plans['student-walk-0.40m_run2']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #4

# %%
p = plans['student-walk-0.40m_run3']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ### Scenario 3: Half mile student walk distance limit

# %% [markdown]
# ##### Run #1

# %%
p = plans['student-walk-0.50m_run0']

# %%
p.map()

# %%
p.animate()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #2

# %%
p = plans['student-walk-0.50m_run1']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #3

# %%
p = plans['student-walk-0.50m_run2']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #4

# %%
p = plans['student-walk-0.50m_run3']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ### Scenario 4: One mile student walk distance limit (half mile for students in grades 6 and below)

# %% [markdown]
# ##### Run #1

# %%
p = plans['student-walk-0.50m-or-1.0m_run0']

# %%
p.map()

# %%
p.animate()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #2

# %%
p = plans['student-walk-0.50m-or-1.0m_run1']

# %%
p.map()

# %%
p.animate()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #3

# %%
p = plans['student-walk-0.50m-or-1.0m_run2']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #4

# %%
p = plans['student-walk-0.50m-or-1.0m_run3']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
plot = p.plot_student_ride_time()

# %% [markdown]
# ### Scenario 5: 0.82 mile student walk distance

# %% [markdown]
# ##### Run #1

# %%
p = plans['student-walk-0.82m_run0']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #2

# %%
p = plans['student-walk-0.82m_run1']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #3

# %%
p = plans['student-walk-0.82m_run2']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %% [markdown]
# ##### Run #4

# %%
p = plans['student-walk-0.82m_run3']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
plot = p.plot_student_ride_time()

# %% [markdown]
# ### Scenario comparison

# %%
s = ['student-walk-0.25m_run1', 'student-walk-0.40m_run1',
     'student-walk-0.50m_run0', 'student-walk-0.50m-or-1.0m_run0',
     'student-walk-0.82m_run1']
plot = pa.comparative_ride_times_plot(plans, s, ex)

# %%
plot = pa.summary_stats_bar_plots(plans, ex)

# %% [markdown]
# ##  Plans without outlier students

# %%
wo = pa.get_all_plans(without_outliers, cm)

# %% [markdown]
# ##### Scenario 1: 0.25 mile student walk distance

# %%
p = wo['student-walk-0.25m_run0']

# %%
p.map()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %%
p.bus_metrics

# %%
p.student_metrics

# %% [markdown]
# ##### Scenario 2: 0.40 mile student walk distance

# %%
p = wo['student-walk-0.40m_run0']

# %%
p.map()

# %%
p.animation()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %%
p.bus_metrics

# %%
p.student_metrics

# %% [markdown]
# ##### Scenario 3: Half mile student walk distance

# %%
p = wo['student-walk-0.50m_run0']

# %%
p.map()

# %%
p.animation()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %%
p.bus_metrics

# %%
p.student_metrics

# %% [markdown]
# ##### Scenario 4: One mile student walk distance limit (half mile for students in grades 6 and below)

# %%
p = wo['student-walk-0.50m-or-1.0m_run0']

# %%
p.map()

# %%
p.animation()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %%
p.bus_metrics

# %%
p.student_metrics

# %% [markdown]
# ##### Scenario 5: 0.82 mile student walk distance

# %%
p = wo['student-walk-0.82m_run0']

# %%
p.map()

# %%
p.animation()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
p.plot_student_ride_time()

# %%
p.bus_metrics

# %%
p.student_metrics

# %%
plot = pa.summary_stats_bar_plots(wo, ex)
