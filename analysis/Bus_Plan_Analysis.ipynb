# %% [markdown]
# # Route Plan Analysis

# %% [markdown]
# Use this notebook to map and analyze a routing plan from Azavea's [School Bus Routing Optimization tool](https://github.com/azavea/bus-plan). After

# %%
routes = "../../map-solver/route1_routes.csv"
stop_assignment = "../../data-wrangling/sample-runs/student1.csv"

# %%
import pandas as pd

import map_solver 
import student_ride_times

# %%
p = pd.read_csv(routes)
p.head()
# Out:
#    route_id  route_sequence  stop_sequence        time          x          y
# 0        12              19              0  1512028919 -75.356600  39.850600
# 1        12              19              1  1512028919 -75.356712  39.850533
# 2        12              19              2  1512028929 -75.357037  39.850949
# 3        12              19              3  1512028945 -75.357654  39.851918
# 4        12              19              4  1512028962 -75.358148  39.852675

# %%
map_solver.map_plan(routes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ride_times = student_ride_times.get_student_ride_times(routes, stop_assignment)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-ece74e59bb9f> in <module>()
# ----> 1 ride_times = student_ride_times.get_student_ride_times(routes, stop_assignment)
#
# ~/files/da_customer/bus_routing/bus-plan/analysis/student_ride_times.py in get_student_ride_times(route_input, student_stop_input)
#      29
#      30 def get_student_ride_times(route_input, student_stop_input):
# ---> 31     route_times = get_route_data(route_input)
#      32     student_times = get_student_stop_data(student_stop_input)
#      33     return pd.merge(student_times, route_times)
#
# ~/files/da_customer/bus_routing/bus-plan/analysis/student_ride_times.py in get_route_data(route_input)
#      12     rt_school.columns = ['route_id', 'arrival_time']
#      13     rt_pickup = rt[rt.stop_sequence==0]
# ---> 14     rt_pickup = rt_pickup[['route_id', 'origin_id', 'time']]
# ...
